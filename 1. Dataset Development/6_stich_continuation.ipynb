# %%
import os
import json
import re

# --- CONFIGURATION ---
# In Jupyter, we use os.getcwd() to get the current folder path
try:
    BASE_DIR = os.path.dirname(os.path.abspath(__file__))
except NameError:
    BASE_DIR = os.getcwd()

RAW_INPUT = os.path.join(BASE_DIR, "raw_mustika_rasa_full.json")
FINAL_OUTPUT = os.path.join(BASE_DIR, "mustika_rasa_full_cleaned.json")

print(f"Working Directory: {BASE_DIR}")
print(f"Looking for: {RAW_INPUT}")
# Out:
# Working Directory: /Users/prasetyoekosulaksono/Documents/bhineka_tunggal_rasa/1. Dataset Development
# Looking for: /Users/prasetyoekosulaksono/Documents/bhineka_tunggal_rasa/1. Dataset Development/raw_mustika_rasa_full.json

# %%
import pandas as pd
import json
import os

def is_continuation(prev, curr):
    if not prev or not curr: 
        return False, None

    curr_title_orig = (curr.get('title_original') or "").lower()
    curr_title_norm = (curr.get('title_normalized') or "").lower()
    
    page_diff = curr.get('_source_page', 999) - prev.get('_source_page', 0)
    is_adjacent = (0 <= page_diff <= 1)
    
    if not is_adjacent:
        return False, None

    # Trigger 1: Keywords
    fragment_keywords = ["continu", "lanjut", "sambung", "untitled"]
    is_explicit_fragment = any(kw in curr_title_orig or kw in curr_title_norm for kw in fragment_keywords)

    # Trigger 2: Previous incomplete
    prev_instr_list = prev.get('instructions') or []
    prev_instr_text = " ".join(prev_instr_list).lower()
    is_prev_incomplete = (
        len(prev_instr_list) == 0 or 
        "incomplete" in prev_instr_text or 
        "missing" in prev_instr_text
    )

    if is_explicit_fragment and is_prev_incomplete:
        return True, "Keyword + Empty Instructions"
    if is_explicit_fragment:
        return True, "Explicit Keyword"
    if is_prev_incomplete and curr.get('recipe_id', '').endswith('_01'):
        return True, "First item on page after incomplete"
        
    return False, None

# %%
def main():
    with open(RAW_INPUT, 'r', encoding='utf-8') as f:
        raw_list = json.load(f)

    if not raw_list: return

    final_recipes = []
    buffer = raw_list[0]

    for i in range(1, len(raw_list)):
        next_item = raw_list[i]
        
        if is_continuation(buffer, next_item):
            print(f"🧵 Target: {buffer['recipe_id']} + {next_item['recipe_id']}")
        else:
            buffer = next_item

# %%
main()
# Out:
# 🧵 Target: MR_196_02 + MR_197_01
# 🧵 Target: MR_201_02 + MR_202_01
# 🧵 Target: MR_203_03 + MR_204_01
# 🧵 Target: MR_205_02 + MR_206_01
# 🧵 Target: MR_209_02 + MR_210_01
# 🧵 Target: MR_228_02 + MR_229_01
# 🧵 Target: MR_234_02 + MR_235_01
# 🧵 Target: MR_240_02 + MR_241_01
# 🧵 Target: MR_248_02 + MR_249_01
# 🧵 Target: MR_250_02 + MR_251_01
# 🧵 Target: MR_255_02 + MR_256_01
# 🧵 Target: MR_259_01 + MR_259_02
# 🧵 Target: MR_262_02 + MR_263_01
# 🧵 Target: MR_263_03 + MR_264_01
# 🧵 Target: MR_267_02 + MR_268_01
# 🧵 Target: MR_277_02 + MR_278_01
# 🧵 Target: MR_282_02 + MR_283_01
# 🧵 Target: MR_286_02 + MR_287_01
# 🧵 Target: MR_294_02 + MR_295_01
# 🧵 Target: MR_295_03 + MR_296_01
# 🧵 Target: MR_296_03 + MR_297_01
# 🧵 Target: MR_302_02 + MR_303_01
# 🧵 Target: MR_303_03 + MR_304_01
# 🧵 Target: MR_304_03 + MR_305_01
# 🧵 Target: MR_307_02 + MR_308_01
# 🧵 Target: MR_309_02 + MR_310_01
# 🧵 Target: MR_313_02 + MR_314_01
# 🧵 Target: MR_314_03 + MR_315_01
# 🧵 Target: MR_325_02 + MR_326_01
# 🧵 Target: MR_326_02 + MR_327_01
# 🧵 Target: MR_329_02 + MR_330_01
# 🧵 Target: MR_335_02 + MR_336_01
# 🧵 Target: MR_336_03 + MR_337_01
# 🧵 Target: MR_347_02 + MR_348_01
# 🧵 Target: MR_365_02 + MR_366_01
# 🧵 Target: MR_373_02 + MR_374_01
# 🧵 Target: MR_375_02 + MR_376_01
# 🧵 Target: MR_379_02 + MR_380_01
# 🧵 Target: MR_382_02 + MR_383_01
# 🧵 Target: MR_385_03 + MR_386_01
# 🧵 Target: MR_393_02 + MR_394_01
# 🧵 Target: MR_394_03 + MR_395_01
# 🧵 Target: MR_398_02 + MR_399_01
# 🧵 Target: MR_400_02 + MR_401_01
# 🧵 Target: MR_407_02 + MR_408_01
# 🧵 Target: MR_409_02 + MR_410_01
# 🧵 Target: MR_416_02 + MR_417_01
# 🧵 Target: MR_417_03 + MR_418_01
# 🧵 Target: MR_419_02 + MR_420_01
# 🧵 Target: MR_423_02 + MR_424_01
# 🧵 Target: MR_431_02 + MR_432_01
# 🧵 Target: MR_432_03 + MR_433_01
# 🧵 Target: MR_433_03 + MR_434_01
# 🧵 Target: MR_444_02 + MR_445_01
# 🧵 Target: MR_448_02 + MR_449_01
# 🧵 Target: MR_453_02 + MR_454_01
# 🧵 Target: MR_455_02 + MR_456_01
# 🧵 Target: MR_456_03 + MR_457_01
# 🧵 Target: MR_461_02 + MR_462_01
# 🧵 Target: MR_463_02 + MR_464_01
# 🧵 Target: MR_475_01 + MR_476_01
# 🧵 Target: MR_479_02 + MR_480_01
# 🧵 Target: MR_482_02 + MR_483_01
# 🧵 Target: MR_484_02 + MR_485_01
# 🧵 Target: MR_490_02 + MR_491_01
# 🧵 Target: MR_502_02 + MR_503_01
# 🧵 Target: MR_511_02 + MR_512_01
# 🧵 Target: MR_513_02 + MR_514_01
# 🧵 Target: MR_518_02 + MR_519_01
# 🧵 Target: MR_522_02 + MR_523_01
# 🧵 Target: MR_524_02 + MR_525_01
# 🧵 Target: MR_539_02 + MR_540_01
# 🧵 Target: MR_549_02 + MR_550_01
# 🧵 Target: MR_550_03 + MR_551_01
# 🧵 Target: MR_558_01 + MR_558_02
# 🧵 Target: MR_574_02 + MR_575_01
# 🧵 Target: MR_583_02 + MR_584_01
# 🧵 Target: MR_587_02 + MR_588_01
# 🧵 Target: MR_590_02 + MR_591_01
# 🧵 Target: MR_592_02 + MR_593_01
# 🧵 Target: MR_609_02 + MR_610_01
# 🧵 Target: MR_622_03 + MR_623_01
# 🧵 Target: MR_626_02 + MR_627_01
# 🧵 Target: MR_636_02 + MR_637_01
# 🧵 Target: MR_640_02 + MR_641_01
# 🧵 Target: MR_649_02 + MR_650_01
# 🧵 Target: MR_655_02 + MR_656_01
# 🧵 Target: MR_659_02 + MR_660_01
# 🧵 Target: MR_660_03 + MR_661_01
# 🧵 Target: MR_669_02 + MR_670_01
# 🧵 Target: MR_673_02 + MR_674_01
# 🧵 Target: MR_679_02 + MR_680_01
# 🧵 Target: MR_688_02 + MR_689_01
# 🧵 Target: MR_689_03 + MR_690_01
# 🧵 Target: MR_696_02 + MR_697_01
# 🧵 Target: MR_707_02 + MR_708_01
# 🧵 Target: MR_710_02 + MR_711_01
# 🧵 Target: MR_732_02 + MR_733_01
# 🧵 Target: MR_736_02 + MR_737_01
# 🧵 Target: MR_741_02 + MR_742_01
# 🧵 Target: MR_763_02 + MR_764_01
# 🧵 Target: MR_774_02 + MR_775_01
# 🧵 Target: MR_777_03 + MR_778_01
# 🧵 Target: MR_780_03 + MR_781_01
# 🧵 Target: MR_781_03 + MR_782_01
# 🧵 Target: MR_784_02 + MR_785_01
# 🧵 Target: MR_789_02 + MR_790_01
# 🧵 Target: MR_790_03 + MR_791_01
# 🧵 Target: MR_793_02 + MR_794_01
# 🧵 Target: MR_804_02 + MR_805_01
# 🧵 Target: MR_813_03 + MR_814_01
# 🧵 Target: MR_814_03 + MR_815_01
# 🧵 Target: MR_823_02 + MR_824_01
# 🧵 Target: MR_827_03 + MR_828_01
# 🧵 Target: MR_846_02 + MR_847_01
# 🧵 Target: MR_856_02 + MR_857_01
# 🧵 Target: MR_858_03 + MR_859_01
# 🧵 Target: MR_866_03 + MR_867_01
# 🧵 Target: MR_867_03 + MR_868_01
# 🧵 Target: MR_880_02 + MR_881_01
# 🧵 Target: MR_888_02 + MR_889_01
# 🧵 Target: MR_918_02 + MR_919_01
# 🧵 Target: MR_930_02 + MR_931_01
# 🧵 Target: MR_931_03 + MR_932_01
# 🧵 Target: MR_961_02 + MR_962_01
# 🧵 Target: MR_972_02 + MR_973_01
# 🧵 Target: MR_978_02 + MR_979_01
# 🧵 Target: MR_992_02 + MR_993_01
# 🧵 Target: MR_995_03 + MR_996_01
# 🧵 Target: MR_1000_02 + MR_1001_01
# 🧵 Target: MR_1013_03 + MR_1014_01
# 🧵 Target: MR_1022_02 + MR_1023_01
# 🧵 Target: MR_1044_02 + MR_1045_01
# 🧵 Target: MR_1050_02 + MR_1051_01
# 🧵 Target: MR_1052_03 + MR_1053_01
# 🧵 Target: MR_1061_02 + MR_1062_01
# 🧵 Target: MR_1062_03 + MR_1063_01
# 🧵 Target: MR_1069_02 + MR_1070_01
# 🧵 Target: MR_1095_01 + MR_1096_01
# 🧵 Target: MR_1097_02 + MR_1098_01
# 🧵 Target: MR_1110_03 + MR_1111_01
# 🧵 Target: MR_1118_02 + MR_1119_01
# 🧵 Target: MR_1128_02 + MR_1129_01
# 🧵 Target: MR_1131_02 + MR_1132_01
# 🧵 Target: MR_1133_02 + MR_1134_01
# 🧵 Target: MR_1163_03 + MR_1164_01
